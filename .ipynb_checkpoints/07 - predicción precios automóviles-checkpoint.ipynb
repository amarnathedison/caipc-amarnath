# %% [markdown]
# Dataset:
#
# https://archive.ics.uci.edu/ml/datasets/automobile

# %%
import pandas as pd
import numpy as np

# %%
coches = pd.read_csv('imports-85.data', names = [
   "symboling",
    "normalized-losses",
    "make",
    "fuel-type",
    "aspiration",
    "num-of-doors",
    "body-style",
    "drive-wheels",
    "engine-location",
    "wheel-base",
    "length",
    "width",
    "height",
    "curb-weight",
    "engine-type",
    "num-of-cylinders",
    "engine-size",
    "fuel-system",
    "bore",
    "stroke",
    "compression-ratio",
    "horsepower",
    "peak-rpm",
    "city-mpg",
    "highway-mpg",
    "price"
])

# %%
coches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# reemplazo toddos los ? por nan (nulos)
coches = coches.replace('?', np.nan)

# %%
coches['normalized-losses']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
coches['normalized-losses'].value_counts()
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: normalized-losses, dtype: int64

# %%
coches['normalized-losses'] = coches['normalized-losses'].astype('float')

# %%
coches
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
coches_numericos = coches[['symboling', 'normalized-losses', 'num-of-doors', 'wheel-base', 'engine-size', 'bore',
                          'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']].copy()

# %%
coches_numericos['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
coches_numericos['num-of-doors'] = coches_numericos['num-of-doors'].apply(lambda x: 4 if x == 'four' else 2)

# %%
coches_numericos
# Out:
#      symboling  normalized-losses  num-of-doors  wheel-base  engine-size  \
# 0            3                NaN             2        88.6          130
# 1            3                NaN             2        88.6          130
# 2            1                NaN             2        94.5          152
# 3            2              164.0             4        99.8          109
# 4            2              164.0             4        99.4          136
# ..         ...                ...           ...         ...          ...
# 200         -1               95.0             4       109.1          141
# 201         -1               95.0             4       109.1          141
# 202         -1               95.0             4       109.1          173
# 203         -1               95.0             4       109.1          145
# 204         -1               95.0             4       109.1          141
#
#      bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
coches_numericos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   num-of-doors       205 non-null    int64
#  3   wheel-base         205 non-null    float64
#  4   engine-size        205 non-null    int64
#  5   bore               201 non-null    object
#  6   stroke             201 non-null    object
#  7   compression-ratio  205 non-null    float64
#  8   horsepower         203 non-null    object
#  9   peak-rpm           203 non-null    object
#  10  city-mpg           205 non-null    int64
#  11  highway-mpg        205 non-null    int64
#  12  price              201 non-null    object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 20.9+ KB

# %%
coches_numericos = coches_numericos.astype('float')

# %%
# el precio es la columna que queremos predecir -  no tienen sentido los datos sin precio
coches_numericos = coches_numericos.dropna(subset=['price'])

# %%
coches_numericos.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# num-of-doors          0
# wheel-base            0
# engine-size           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
coches_numericos['horsepower'] = coches_numericos['horsepower'].fillna(coches_numericos['horsepower'].mean())

# %%
coches_numericos.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# num-of-doors          0
# wheel-base            0
# engine-size           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            0
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
coches_numericos.mean()
# Out:
# symboling                0.840796
# normalized-losses      122.000000
# num-of-doors             3.124378
# wheel-base              98.797015
# engine-size            126.875622
# bore                     3.330711
# stroke                   3.256904
# compression-ratio       10.164279
# horsepower             103.396985
# peak-rpm              5117.587940
# city-mpg                25.179104
# highway-mpg             30.686567
# price                13207.129353
# dtype: float64

# %%
coches_numericos = coches_numericos.fillna(coches_numericos.mean())

# %%
coches_numericos.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# num-of-doors         0
# wheel-base           0
# engine-size          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Normalizamos las columnas
price = coches_numericos['price']
coches_numericos = (coches_numericos - coches_numericos.mean())/coches_numericos.std()

# %%
coches_numericos['price'] = price

# %%
coches_numericos
# Out:
#      symboling  normalized-losses  num-of-doors  wheel-base  engine-size  \
# 0     1.720753           0.000000     -1.130355   -1.680910     0.075201
# 1     1.720753           0.000000     -1.130355   -1.680910     0.075201
# 2     0.126876           0.000000     -1.130355   -0.708334     0.604724
# 3     0.923814           1.312654      0.880276    0.165335    -0.430252
# 4     0.923814           1.312654      0.880276    0.099398     0.219617
# ..         ...                ...           ...         ...          ...
# 200  -1.467002          -0.843849      0.880276    1.698379     0.339963
# 201  -1.467002          -0.843849      0.880276    1.698379     0.339963
# 202  -1.467002          -0.843849      0.880276    1.698379     1.110178
# 203  -1.467002          -0.843849      0.880276    1.698379     0.436240
# 204  -1.467002          -0.843849      0.880276    1.698379     0.339963
#
#          bore    stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# ...

# %% [markdown]
# # univariate

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
def knn_train_test(train_col, target_col, df):
    """
    Calcule la predicción y me devuelva el RMSE en base a una serie de columnas 
    predictoras y una target a predecir
    """
    # Crearemos la instancia del objeto de KNeighborsRegressor
    # Barajaremos las filas en el dataframe
    # Crearemos los conjuntos de entrenamiento y de test
    # Haremos el fit del model usando k=5
    # Crearemos las predicciones 
    # Calcularemos y devolveremos el rmse

# %%
# Calcular el RMSE de cada una de las columnas numéricas
# veremos qué columnas nos predice mejor el precio

# %%
# multivariate
# comprobaremos varias combinaciones, incluyendo la de 'todas las columnas'

# probaremos varios valores de k
